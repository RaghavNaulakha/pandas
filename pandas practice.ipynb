# %%
import pandas as pd
import numpy as np

# %%
dict1= {
    "name":["a","b","c","d"],
    "marks":[12,43,24,76],
    "city":["delhi","bombay","chennai","jaipur"],
    
}

# %%
dict1
# Out:
# {'name': ['a', 'b', 'c', 'd'],
#  'marks': [12, 43, 24, 76],
#  'city': ['delhi', 'bombay', 'chennai', 'jaipur']}

# %%
df= pd.DataFrame(dict1)

# %%
df
# Out:
#   name  marks     city
# 0    a     12    delhi
# 1    b     43   bombay
# 2    c     24  chennai
# 3    d     76   jaipur

# %%
df.head(2)
# Out:
#   name  marks    city
# 0    a     12   delhi
# 1    b     43  bombay

# %%
df.tail(2)
# Out:
#   name  marks     city
# 2    c     24  chennai
# 3    d     76   jaipur

# %%
df.describe()
# Out:
#           marks
# count   4.00000
# mean   38.75000
# std    27.92102
# min    12.00000
# 25%    21.00000
# 50%    33.50000
# 75%    51.25000
# max    76.00000

# %%
df.to_csv("1.csv")

# %%
df.to_csv("1.csv",index=False)

# %%
abc = pd.read_csv('2.csv')

# %%
abc
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  train  no.  speed     city
# 0             0             0           0      123345     76   mumbai
# 1             1             1           1      123456     78  chennai
# 2             2             2           2      123987     96   jaipur
# 3             3             3           3      858585    105    delhi

# %%
abc['speed'][2]
# Out:
# 96

# %%
abc['speed'][2]=96
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_6864\3874728732.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   abc['speed'][2]=96

# %%
abc
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  train  no.  speed     city
# 0             0             0           0      123345     76   mumbai
# 1             1             1           1      123456     78  chennai
# 2             2             2           2      123987     96   jaipur
# 3             3             3           3      858585    105    delhi

# %%
abc.to_csv('2.csv')

# %%
abc.index = ['(i)','(ii)','(iii)','(iv)']

# %%
abc
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  train  no.  speed     city
# (i)               0             0           0      123345     76   mumbai
# (ii)              1             1           1      123456     78  chennai
# (iii)             2             2           2      123987     96   jaipur
# (iv)              3             3           3      858585    105    delhi

# %%
ser = pd.Series(np.random.rand(20))

# %%
ser
# Out:
# 0     0.410133
# 1     0.509664
# 2     0.513120
# 3     0.205892
# 4     0.961204
# 5     0.192174
# 6     0.528552
# 7     0.101530
# 8     0.738380
# 9     0.795780
# 10    0.281548
# 11    0.261888
# 12    0.466826
# 13    0.222218
# 14    0.072076
# 15    0.197469
# 16    0.987095
# 17    0.909438
# 18    0.062794
# 19    0.719533
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(300,6),index=np.arange(300))

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf
# Out:
#             0         1         2         3         4         5
# 0    0.793227  0.776229  0.918503  0.159522  0.803067  0.850289
# 1    0.984175  0.012303  0.764292  0.032343  0.787928  0.170426
# 2    0.968247  0.550134  0.339415  0.798204  0.743617  0.540260
# 3    0.329089  0.662584  0.005731  0.949342  0.260886  0.930582
# 4    0.425650  0.784145  0.692026  0.331375  0.633142  0.612056
# ..        ...       ...       ...       ...       ...       ...
# 295  0.912950  0.221229  0.176968  0.621145  0.587184  0.347967
# 296  0.177183  0.401233  0.886232  0.496882  0.134403  0.798450
# 297  0.272994  0.149323  0.195697  0.579226  0.989132  0.568634
# 298  0.489479  0.067766  0.959896  0.167591  0.234250  0.754356
# 299  0.474962  0.068524  0.670774  0.225297  0.587096  0.340572
#
# [300 rows x 6 columns]

# %%
newdf.head(6)
# Out:
#           0         1         2         3         4         5
# 0  0.793227  0.776229  0.918503  0.159522  0.803067  0.850289
# 1  0.984175  0.012303  0.764292  0.032343  0.787928  0.170426
# 2  0.968247  0.550134  0.339415  0.798204  0.743617  0.540260
# 3  0.329089  0.662584  0.005731  0.949342  0.260886  0.930582
# 4  0.425650  0.784145  0.692026  0.331375  0.633142  0.612056
# 5  0.184820  0.968239  0.868979  0.008259  0.742326  0.268915

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# 5    float64
# dtype: object

# %%
newd
# 40   0.043108  0.182455  0.492496  0.387985  0.658063  0.265083
# 44   0.192898  0.699520  0.572899  0.707297  0.736649  0.308166
# 53   0.008947  0.505634  0.101844  0.768375  0.896184  0.628022
# 55   0.075641  0.742982  0.788831  0.372721  0.923330  0.001316
# 62   0.093872  0.193104  0.440169  0.480851  0.697640  0.205051
# 64   0.043331  0.391322  0.539220  0.444796  0.773669  0.432751
# 71   0.086697  0.792785  0.163466  0.788590  0.929526  0.912883
# 85   0.102486  0.196856  0.005258  0.430051  0.776709  0.840894
# 119  0.021023  0.490109  0.294301  0.722388  0.676177  0.082056
# 126  0.108134  0.295436  0.637182  0.550900  0.609956  0.044531
# ...

# %%
newdf.loc[0,'a']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\Coincent_DataScience(python)\Pandas-main\Practice\pandas practice.ipynb Cell 48' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Coincent_DataScience%28python%29/Pandas-main/Practice/pandas%20practice.ipynb#ch0000047?line=0'>1</a> newdf.loc[0,'a']
#
# File c:\Users\KIIT\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:960, in _LocationIndexer.__getitem__(self, key)
#     958     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     959     if self._is_scalar_access(key):
# --> 960         return self.obj._get_value(*key, takeable=self._takeable)
#     961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#
# ...

# %%
newdf.columns =list('abcdef')

# %%
newdf.head()
# Out:
#           a         b         c         d         e         f
# 0     65432  0.910369  0.160638  0.963273  0.829333  0.355277
# 1  0.489823  0.557605  0.178522  0.549875  0.378007  0.743718
# 2  0.141061  0.388333  0.026108  0.183534  0.317178  0.888458
# 3  0.182129  0.219731  0.617087  0.081892  0.465274  0.099048
# 4  0.432829  0.638312  0.785818  0.804137  0.322691  0.040020

# %%
newdf.loc[0,'e']
# Out:
# 0.8293325465268496

# %%
newdf.iloc[0,4]
# Out:
# 0.8293325465268496

# %%
newdf.iloc[[0,296],[0,4]]
# Out:
#             a         e
# 0       65432  0.829333
# 296  0.192664  0.586686

# %%
newdf.loc[[0,296],['a','e']]
# Out:
#             a         e
# 0       65432  0.829333
# 296  0.192664  0.586686

# %%
newdf.head(3)
# Out:
#           a         b         c         d         e         f
# 0     65432  0.910369  0.160638  0.963273  0.829333  0.355277
# 1  0.489823  0.557605  0.178522  0.549875  0.378007  0.743718
# 2  0.141061  0.388333  0.026108  0.183534  0.317178  0.888458

# %%
newdf.drop(['a','c'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9316/3690255472.py in <module>
# ----> 1 newdf.drop(['a','c'],axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
# ...

# %%
newdf
# Out:
#             b         d         e         f
# 0    0.910369  0.963273  0.829333  0.355277
# 1    0.557605  0.549875  0.378007  0.743718
# 2    0.388333  0.183534  0.317178  0.888458
# 3    0.219731  0.081892  0.465274  0.099048
# 4    0.638312  0.804137  0.322691  0.040020
# ..        ...       ...       ...       ...
# 295  0.440987  0.862931  0.970982  0.432178
# 296  0.152708  0.034499  0.586686  0.508492
# 297  0.025293  0.711797  0.420969  0.352099
# 298  0.750041  0.693354  0.744628  0.452892
# 299  0.928527  0.753071  0.890944  0.389557
#
# [300 rows x 4 columns]

# %%
newdf=newdf.drop([0,3],axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9316/3983814333.py in <module>
# ----> 1 newdf=newdf.drop([0,3],axis=0)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
newdf
# Out:
#             b         d         e         f
# 1    0.557605  0.549875  0.378007  0.743718
# 2    0.388333  0.183534  0.317178  0.888458
# 4    0.638312  0.804137  0.322691  0.040020
# 5    0.408556  0.451725  0.521080  0.692187
# 6    0.827985  0.356716  0.831559  0.128457
# ..        ...       ...       ...       ...
# 295  0.440987  0.862931  0.970982  0.432178
# 296  0.152708  0.034499  0.586686  0.508492
# 297  0.025293  0.711797  0.420969  0.352099
# 298  0.750041  0.693354  0.744628  0.452892
# 299  0.928527  0.753071  0.890944  0.389557
#
# [298 rows x 4 columns]

# %%
newdf.reset_index(drop=True,inplace=True)

# %%
newdf.head()
# Out:
#    level_0  index         b         d         e         f
# 0        0      1  0.557605  0.549875  0.378007  0.743718
# 1        1      2  0.388333  0.183534  0.317178  0.888458
# 2        2      4  0.638312  0.804137  0.322691  0.040020
# 3        3      5  0.408556  0.451725  0.521080  0.692187
# 4        4      6  0.827985  0.356716  0.831559  0.128457

# %%
newdf
# Out:
#      level_0  index         b         d         e         f
# 0          0      1  0.557605  0.549875  0.378007  0.743718
# 1          1      2  0.388333  0.183534  0.317178  0.888458
# 2          2      4  0.638312  0.804137  0.322691  0.040020
# 3          3      5  0.408556  0.451725  0.521080  0.692187
# 4          4      6  0.827985  0.356716  0.831559  0.128457
# ..       ...    ...       ...       ...       ...       ...
# 293      293    295  0.440987  0.862931  0.970982  0.432178
# 294      294    296  0.152708  0.034499  0.586686  0.508492
# 295      295    297  0.025293  0.711797  0.420969  0.352099
# 296      296    298  0.750041  0.693354  0.744628  0.452892
# 297      297    299  0.928527  0.753071  0.890944  0.389557
#
# [298 rows x 6 columns]

# %%
newdf.shape
# Out:
# (298, 6)

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298 entries, 0 to 297
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   level_0  298 non-null    int64
#  1   index    298 non-null    int64
#  2   b        298 non-null    float64
#  3   d        298 non-null    float64
#  4   e        298 non-null    float64
#  5   f        298 non-null    float64
# dtypes: float64(4), int64(2)
# memory usage: 14.1 KB

# %%
df1=pd.DataFrame(np.random.rand(3,2))

# %% [markdown]
# #

# %%
df1
# Out:
#           0         1
# 0  0.106114  0.637405
# 1  0.067362  0.043694
# 2  0.841059  0.755141

# %%
df1.describe()
# Out:
#               0         1
# count  3.000000  3.000000
# mean   0.338178  0.478746
# std    0.435938  0.381338
# min    0.067362  0.043694
# 25%    0.086738  0.340549
# 50%    0.106114  0.637405
# 75%    0.473587  0.696273
# max    0.841059  0.755141

# %%
df1.mean()
# Out:
# 0    0.338178
# 1    0.478746
# dtype: float64

# %%
df1.corr()
# Out:
#           0         1
# 0  1.000000  0.661677
# 1  0.661677  1.000000

# %%
df1.count()
# Out:
# 0    3
# 1    3
# dtype: int64

# %%
df1.max()
# Out:
# 0    0.841059
# 1    0.755141
# dtype: float64

# %%
df1.min()
# Out:
# 0    0.067362
# 1    0.043694
# dtype: float64

# %%
df1.median()
# Out:
# 0    0.106114
# 1    0.637405
# dtype: float64

# %%
df1.std()
# Out:
# 0    0.435938
# 1    0.381338
# dtype: float64

# %%
data= pd.read_excel('excel.xlsx',sheet_name='Sheet2')

# %%
data
# Out:
#    Unnamed: 02  train  no. 2  speed2    city2
# 0            0        123345      76   mumbai
# 1            1        123456      78  chennai
# 2            2        123987      96   jaipur
# 3            3        858585     105    delhi

# %%
data.iloc[0,1]=45

# %%
data
# Out:
#    Unnamed: 02  train  no. 2  speed2    city2
# 0            0            45      76   mumbai
# 1            1        123456      78  chennai
# 2            2        123987      96   jaipur
# 3            3        858585     105    delhi

# %%
data.to_excel('excel.xlsx',sheet_name='Sheet2')
